# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# Implementing a Cascade CNN RNN for EEG classification using PyTorch
# Author: Di Wu, ECE, UW--Madison, WI, USA; Email: di.wu@ece.wisc.edu
# mainly refering to:
# 1: URL: https://github.com/dalinzhang/Cascade-Parallel
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

import os
import sys
import pandas as pd
import pickle
import numpy as np
import time

import math
import warnings
import numbers
from typing import List, Tuple, Optional, overload, Union

import torch
from torch._C import dtype
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch import Tensor
from torch.utils.data import TensorDataset, DataLoader
from torchsummaryX import summary

from binary_model import Cascade_CNN_RNN_Binary

# %%
input_sz=(10, 11) # size of each window
linear_act="relu" # activation in CNN
cnn_chn=32 # channle in CNN
cnn_kn_sz=3 # kernel (height, width) in CNN
cnn_padding=0 # kernel (height, width) in CNN
fc_sz=1024 # fc size in CNN
rnn_win_sz=10 # window size in RNN
rnn_hidden_sz=1024 # hidden size in RNN
rnn_hard=False # flag to apply HardGRUCell RNN
keep_prob=0.5 # prob for drop out after each FC
num_class=5 # output size
bin_train_batch_sz=1024 # train batch size for binary model
bin_test_batch_sz=1024 # test batch size for binary model
training_epochs=300 # train epoch
pin_memory=True
non_blocking=False
lr=1e-4
enable_penalty=False
lambda_loss_amount=0.0005
np.random.seed(33)

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# device configuration
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    torch.backends.cudnn.benchmark = True
    print("Using CUDA...")
# Out:
# Using CUDA...

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# dataset configuration
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
print("******************** Dataset Configuration Start ********************")
dataset_dir = "./preprocessed_data/"

with open(dataset_dir+"preprocessed_1_108_shuffle_dataset_3D_win_10.pkl", "rb") as fp:
      datasets = pickle.load(fp)
with open(dataset_dir+"preprocessed_1_108_shuffle_labels_3D_win_10.pkl", "rb") as fp:
      labels = pickle.load(fp)

datasets = datasets.reshape(len(datasets), rnn_win_sz, input_sz[0], input_sz[1], 1)
one_hot_labels = np.array(list(pd.get_dummies(labels)))
labels = np.asarray(pd.get_dummies(labels), dtype = np.int8)

split = np.random.rand(len(datasets)) < 0.75

train_x = datasets[split]
train_y = labels[split]

train_sample = len(train_x)
print("# of train samples:", train_sample)
print(train_x.max())
print(train_x.min())
print(np.abs(train_x).mean())
print((np.sum(train_x > 1) + np.sum(train_x < -1))/train_sample/10/11/10)

train_x_tensor = torch.Tensor(train_x).squeeze(-1)
train_y_tensor = torch.argmax(torch.Tensor(train_y), dim=1)
print(train_x_tensor.shape)
print(train_y_tensor.shape)
train_dataset = TensorDataset(train_x_tensor, train_y_tensor)
train_dataloader = DataLoader(
                                train_dataset, 
                                batch_size=bin_train_batch_sz, 
                                shuffle=False, 
                                num_workers=4, 
                                pin_memory=pin_memory, 
                                drop_last=True
                                )

test_x = datasets[~split]
test_y = labels[~split]

test_sample = len(test_x)
print("# of test samples:", test_sample)

test_x_tensor = torch.Tensor(test_x).squeeze(-1)
test_y_tensor = torch.argmax(torch.Tensor(test_y), dim=1)

test_dataset = TensorDataset(test_x_tensor, test_y_tensor)
test_dataloader = DataLoader(
                                test_dataset, 
                                batch_size=bin_test_batch_sz, 
                                shuffle=False, 
                                num_workers=4,
                                pin_memory=pin_memory, 
                                drop_last=True
                                )

print("********************* Dataset Configuration End *********************\n")

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# model configuration
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
print("********************* Model Configuration Start *********************")
model = Cascade_CNN_RNN_Binary(input_sz=input_sz, # size of each window
                                linear_act=linear_act, # activation in CNN
                                cnn_chn=cnn_chn, # input channle in CNN
                                cnn_kn_sz=cnn_kn_sz, # kernel (height, width) in CNN
                                cnn_padding=cnn_padding, # kernel (height, width) in CNN
                                fc_sz=fc_sz, # fc size in CNN and MLP
                                rnn_win_sz=rnn_win_sz, # window size in RNN
                                rnn_hidden_sz=rnn_hidden_sz, # hidden size in RNN
                                rnn_hard=rnn_hard, # flag to apply HardGRUCell RNN
                                keep_prob=keep_prob, # prob for drop out after each FC
                                num_class=num_class) # output size
model.to(device)
summary(model, torch.zeros((3, 1, rnn_win_sz, input_sz[0], input_sz[1])).to(device))
print("********************** Model Configuration End **********************\n")
# Out:
# ******************** Dataset Configuration Start ********************
# # of train samples: 468024
# 7.880674169755176
# -7.877568076942479
# 0.4396715189100413
# 0.15966894277371943
# torch.Size([468024, 10, 10, 11])
# torch.Size([468024])
# # of test samples: 156235
# ********************* Dataset Configuration End *********************
#
# ********************* Model Configuration Start *********************
# =====================================================================
#                 Kernel Shape     Output Shape     Params   Mult-Adds
# Layer
# 0_conv1        [1, 32, 3, 3]   [30, 32, 8, 9]      320.0     20.736k
# 1_conv1_act                -   [30, 32, 8, 9]          -           -
# 2_conv2       [32, 64, 3, 3]   [30, 64, 6, 7]    18.496k    774.144k
# 3_conv2_act                -   [30, 64, 6, 7]          -           -
# 4_conv3      [64, 128, 3, 3]  [30, 128, 4, 5]    73.856k    1.47456M
# 5_conv3_act                -  [30, 128, 4, 5]          -           -
# 6_fc4           [2560, 1024]       [30, 1024]  2.622464M    2.62144M
# 7_fc4_act                  -       [30, 1024]          -           -
# 8_fc4_drop                 -       [30, 1024]          -           -
# 9_gru6                     -    [10, 3, 1024]   12.5952M  12.582912M
# 10_fc7          [1024, 1024]        [3, 1024]    1.0496M   1.048576M
# 11_fc7_act                 -        [3, 1024]          -           -
# 12_fc7_drop                -        [3, 1024]          -           -
# 13_fc8             [1024, 5]           [3, 5]     5.125k       5.12k
# 14_sm                      -           [3, 5]          -           -
# ---------------------------------------------------------------------
#                           Totals
# Total params          16.365061M
# Trainable params      16.365061M
# Non-trainable params         0.0
# Mult-Adds             18.527488M
# =====================================================================
# ********************** Model Configuration End **********************

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# train
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
print("**************************** Train Start ****************************")
criterion0 = nn.MSELoss()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

for epoch in range(training_epochs):
    model.train()
    total_time = time.time()
    load_time = 0.0
    forward_time = 0.0
    backward_time = 0.0
    for i, data in enumerate(train_dataloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        start_time = time.time()
        inputs, labels = data[0].to(device, non_blocking=non_blocking), data[1].to(device, non_blocking=non_blocking)
        load_time += time.time() - start_time
        
        start_time = time.time()
        # zero the parameter gradients
        optimizer.zero_grad()
        # forward
        outputs = model(inputs)
        if enable_penalty is True:
            loss = criterion(outputs, labels) + lambda_loss_amount * criterion0(outputs, labels)
        else:
            loss = criterion(outputs, labels)
        forward_time += time.time() - start_time
        
        start_time = time.time()
        # backward
        loss.backward()
        # optimize
        optimizer.step()
        backward_time += time.time() - start_time
        
    print("\tTrain load: %.2f sec; forward: %.2f sec; backward: %.2f sec" %(load_time, forward_time, backward_time))
    
    load_time = 0.0
    forward_time = 0.0
    backward_time = 0.0
    model.eval()
#     model.apply(clipper)
    correct = 0
    total = 0
    with torch.no_grad():
        for data in test_dataloader:
            start_time = time.time()
            inputs, labels = data[0].to(device, non_blocking=non_blocking), data[1].to(device, non_blocking=non_blocking)
            load_time += time.time() - start_time
            
            start_time = time.time()
            outputs = model(inputs)
            forward_time += time.time() - start_time
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    print("\tTest load: %.2f sec; forward: %.2f sec; backward: %.2f sec" %(load_time, forward_time, backward_time))

    print('Train - Epoch %d, Loss: %f, Test Accuracy: %f %%' \
          % (epoch, loss.detach().cpu().item(), 100 * correct / total))
    
    print("\tTotal: %.2f sec" %(time.time() - total_time))

print("***************************** Train End *****************************\n")
# Out:
# **************************** Train Start ****************************
# 	Train load: 23.15 sec; forward: 1.54 sec; backward: 2.56 sec
# 	Test load: 0.03 sec; forward: 0.24 sec; backward: 0.00 sec
# Train - Epoch 0, Loss: 1.562473, Test Accuracy: 33.902138 %
# 	Total: 32.54 sec
# 	Train load: 23.28 sec; forward: 1.03 sec; backward: 2.10 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 1, Loss: 1.562952, Test Accuracy: 33.902138 %
# 	Total: 30.60 sec
# 	Train load: 23.31 sec; forward: 1.03 sec; backward: 2.09 sec
# 	Test load: 0.03 sec; forward: 0.24 sec; backward: 0.00 sec
# Train - Epoch 2, Loss: 1.562349, Test Accuracy: 33.902138 %
# 	Total: 30.65 sec
# 	Train load: 23.41 sec; forward: 1.01 sec; backward: 2.10 sec
# 	Test load: 0.04 sec; forward: 0.24 sec; backward: 0.00 sec
# Train - Epoch 3, Loss: 1.564162, Test Accuracy: 33.902138 %
# 	Total: 30.73 sec
# 	Train load: 23.45 sec; forward: 1.01 sec; backward: 2.10 sec
# 	Test load: 0.05 sec; forward: 0.22 sec; backward: 0.00 sec
# Train - Epoch 4, Loss: 1.563168, Test Accuracy: 33.902138 %
# 	Total: 30.78 sec
# 	Train load: 23.43 sec; forward: 1.02 sec; backward: 2.08 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 5, Loss: 1.562026, Test Accuracy: 33.902138 %
# 	Total: 30.76 sec
# 	Train load: 23.40 sec; forward: 1.02 sec; backward: 2.09 sec
# 	Test load: 0.05 sec; forward: 0.22 sec; backward: 0.00 sec
# Train - Epoch 6, Loss: 1.562274, Test Accuracy: 33.902138 %
# 	Total: 30.76 sec
# 	Train load: 23.41 sec; forward: 1.03 sec; backward: 2.09 sec
# 	Test load: 0.06 sec; forward: 0.22 sec; backward: 0.00 sec
# Train - Epoch 7, Loss: 1.559211, Test Accuracy: 33.902138 %
# 	Total: 30.77 sec
# 	Train load: 23.39 sec; forward: 1.02 sec; backward: 2.10 sec
# 	Test load: 0.05 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 8, Loss: 1.556051, Test Accuracy: 33.902781 %
# 	Total: 30.75 sec
# 	Train load: 23.34 sec; forward: 1.02 sec; backward: 2.10 sec
# 	Test load: 0.04 sec; forward: 0.24 sec; backward: 0.00 sec
# Train - Epoch 9, Loss: 1.549314, Test Accuracy: 33.485172 %
# 	Total: 30.67 sec
# 	Train load: 23.18 sec; forward: 1.02 sec; backward: 2.10 sec
# 	Test load: 0.04 sec; forward: 0.24 sec; backward: 0.00 sec
# Train - Epoch 10, Loss: 1.535593, Test Accuracy: 30.951891 %
# 	Total: 30.52 sec
# 	Train load: 23.20 sec; forward: 1.03 sec; backward: 2.08 sec
# 	Test load: 0.05 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 11, Loss: 1.534784, Test Accuracy: 32.200863 %
# 	Total: 30.50 sec
# 	Train load: 23.21 sec; forward: 1.02 sec; backward: 2.08 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 12, Loss: 1.537246, Test Accuracy: 33.340615 %
# 	Total: 30.50 sec
# 	Train load: 23.20 sec; forward: 1.01 sec; backward: 2.09 sec
# 	Test load: 0.04 sec; forward: 0.24 sec; backward: 0.00 sec
# Train - Epoch
sec; backward: 2.07 sec
# 	Test load: 0.05 sec; forward: 0.22 sec; backward: 0.00 sec
# Train - Epoch 257, Loss: 1.136685, Test Accuracy: 25.397692 %
# 	Total: 30.70 sec
# 	Train load: 23.38 sec; forward: 1.01 sec; backward: 2.08 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 258, Loss: 1.149615, Test Accuracy: 24.789268 %
# 	Total: 30.70 sec
# 	Train load: 23.36 sec; forward: 1.00 sec; backward: 2.09 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 259, Loss: 1.139454, Test Accuracy: 23.942486 %
# 	Total: 30.68 sec
# 	Train load: 23.36 sec; forward: 1.03 sec; backward: 2.06 sec
# 	Test load: 0.05 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 260, Loss: 1.141896, Test Accuracy: 24.570184 %
# 	Total: 30.70 sec
# 	Train load: 23.35 sec; forward: 1.03 sec; backward: 2.09 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 261, Loss: 1.124157, Test Accuracy: 24.662058 %
# 	Total: 30.66 sec
# 	Train load: 23.37 sec; forward: 1.00 sec; backward: 2.11 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 262, Loss: 1.133000, Test Accuracy: 24.507221 %
# 	Total: 30.71 sec
# 	Train load: 23.35 sec; forward: 1.01 sec; backward: 2.09 sec
# 	Test load: 0.04 sec; forward: 0.22 sec; backward: 0.00 sec
# Train - Epoch 263, Loss: 1.141252, Test Accuracy: 24.058774 %
# 	Total: 30.68 sec
# 	Train load: 23.36 sec; forward: 1.00 sec; backward: 2.12 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 264, Loss: 1.146921, Test Accuracy: 25.037906 %
# 	Total: 30.68 sec
# 	Train load: 23.37 sec; forward: 1.01 sec; backward: 2.08 sec
# 	Test load: 0.04 sec; forward: 0.22 sec; backward: 0.00 sec
# Train - Epoch 265, Loss: 1.131244, Test Accuracy: 24.371659 %
# 	Total: 30.69 sec
# 	Train load: 23.38 sec; forward: 1.00 sec; backward: 2.10 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 266, Loss: 1.138200, Test Accuracy: 24.780916 %
# 	Total: 30.69 sec
# 	Train load: 23.37 sec; forward: 1.00 sec; backward: 2.10 sec
# 	Test load: 0.05 sec; forward: 0.22 sec; backward: 0.00 sec
# Train - Epoch 267, Loss: 1.141405, Test Accuracy: 24.495014 %
# 	Total: 30.69 sec
# 	Train load: 23.38 sec; forward: 1.01 sec; backward: 2.09 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 268, Loss: 1.145014, Test Accuracy: 24.663343 %
# 	Total: 30.70 sec
# 	Train load: 23.22 sec; forward: 1.01 sec; backward: 2.07 sec
# 	Test load: 0.03 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 269, Loss: 1.140837, Test Accuracy: 24.474455 %
# 	Total: 30.55 sec
# 	Train load: 23.37 sec; forward: 1.01 sec; backward: 2.10 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 270, Loss: 1.127456, Test Accuracy: 25.336657 %
# 	Total: 30.69 sec
# 	Train load: 23.38 sec; forward: 1.01 sec; backward: 2.09 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 271, Loss: 1.146094, Test Accuracy: 24.449399 %
# 	Total: 30.69 sec
# 	Train load: 23.23 sec; forward: 1.01 sec; backward: 2.09 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 272, Loss: 1.136272, Test Accuracy: 24.236739 %
# 	Total: 30.53 sec
# 	Train load: 23.38 sec; forward: 1.01 sec; backward: 2.10 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 273, Loss: 1.133527, Test Accuracy: 24.389006 %
# 	Total: 30.68 sec
# 	Train load: 23.38 sec; forward: 1.00 sec; backward: 2.09 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 274, Loss: 1.132126, Test Accuracy: 24.701249 %
# 	Total: 30.70 sec
# 	Train load: 23.38 sec; forward: 1.01 sec; backward: 2.07 sec
# 	Test load: 0.05 sec; forward: 0.24 sec; backward: 0.00 sec
# Train - Epoch 275, Loss: 1.149000, Test Accuracy: 24.758429 %
# 	Total: 30.70 sec
# 	Train load: 23.37 sec; forward: 1.01 sec; backward: 2.10 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 276, Loss: 1.140293, Test Accuracy: 24.879215 %
# 	Total: 30.69 sec
# 	Train load: 23.35 sec; forward: 1.03 sec; backward: 2.06 sec
# 	Test load: 0.05 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 277, Loss: 1.136121, Test Accuracy: 24.732730 %
# 	Total: 30.68 sec
# 	Train load: 23.37 sec; forward: 1.01 sec; backward: 2.10 sec
# 	Test load: 0.05 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 278, Loss: 1.137836, Test Accuracy: 24.576609 %
# 	Total: 30.68 sec
# 	Train load: 23.38 sec; forward: 1.02 sec; backward: 2.07 sec
# 	Test load: 0.06 sec; forward: 0.22 sec; backward: 0.00 sec
# Train - Epoch 279, Loss: 1.119912, Test Accuracy: 24.220035 %
# 	Total: 30.72 sec
# 	Train load: 23.37 sec; forward: 1.00 sec; backward: 2.08 sec
# 	Test load: 0.04 sec; forward: 0.24 sec; backward: 0.00 sec
# Train - Epoch 280, Loss: 1.117935, Test Accuracy: 24.445544 %
# 	Total: 30.70 sec
# 	Train load: 23.39 sec; forward: 1.02 sec; backward: 2.08 sec
# 	Test load: 0.05 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 281, Loss: 1.125890, Test Accuracy: 25.017347 %
# 	Total: 30.71 sec
# 	Train load: 23.38 sec; forward: 1.02 sec; backward: 2.09 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 282, Loss: 1.132773, Test Accuracy: 24.492444 %
# 	Total: 30.71 sec
# 	Train load: 23.36 sec; forward: 1.00 sec; backward: 2.12 sec
# 	Test load: 0.05 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 283, Loss: 1.154569, Test Accuracy: 24.823319 %
# 	Total: 30.69 sec
# 	Train load: 23.38 sec; forward: 1.00 sec; backward: 2.09 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 284, Loss: 1.118043, Test Accuracy: 24.967234 %
# 	Total: 30.70 sec
# 	Train load: 23.37 sec; forward: 1.00 sec; backward: 2.09 sec
# 	Test load: 0.04 sec; forward: 0.24 sec; backward: 0.00 sec
# Train - Epoch 285, Loss: 1.146679, Test Accuracy: 24.501439 %
# 	Total: 30.70 sec
# 	Train load: 23.36 sec; forward: 1.01 sec; backward: 2.09 sec
# 	Test load: 0.05 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 286, Loss: 1.139590, Test Accuracy: 24.861225 %
# 	Total: 30.71 sec
# 	Train load: 23.37 sec; forward: 1.00 sec; backward: 2.08 sec
# 	Test load: 0.05 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 287, Loss: 1.142341, Test Accuracy: 24.275288 %
# 	Total: 30.70 sec
# 	Train load: 23.37 sec; forward: 1.01 sec; backward: 2.09 sec
# 	Test load: 0.05 sec; forward: 0.24 sec; backward: 0.00 sec
# Train - Epoch 288, Loss: 1.124148, Test Accuracy: 24.610660 %
# 	Total: 30.70 sec
# 	Train load: 23.36 sec; forward: 1.00 sec; backward: 2.10 sec
# 	Test load: 0.05 sec; forward: 0.22 sec; backward: 0.00 sec
# Train - Epoch 289, Loss: 1.119747, Test Accuracy: 25.181821 %
# 	Total: 30.69 sec
# 	Train load: 23.39 sec; forward: 1.01 sec; backward: 2.08 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 290, Loss: 1.115016, Test Accuracy: 25.003855 %
# 	Total: 30.69 sec
# 	Train load: 23.37 sec; forward: 1.03 sec; backward: 2.07 sec
# 	Test load: 0.05 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 291, Loss: 1.146911, Test Accuracy: 24.924830 %
# 	Total: 30.71 sec
# 	Train load: 23.37 sec; forward: 0.99 sec; backward: 2.08 sec
# 	Test load: 0.04 sec; forward: 0.24 sec; backward: 0.00 sec
# Train - Epoch 292, Loss: 1.152780, Test Accuracy: 23.935418 %
# 	Total: 30.70 sec
# 	Train load: 23.36 sec; forward: 1.01 sec; backward: 2.09 sec
# 	Test load: 0.05 sec; forward: 0.22 sec; backward: 0.00 sec
# Train - Epoch 293, Loss: 1.127528, Test Accuracy: 24.697394 %
# 	Total: 30.67 sec
# 	Train load: 23.37 sec; forward: 0.99 sec; backward: 2.09 sec
# 	Test load: 0.05 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 294, Loss: 1.131437, Test Accuracy: 24.696752 %
# 	Total: 30.67 sec
# 	Train load: 23.39 sec; forward: 1.02 sec; backward: 2.07 sec
# 	Test load: 0.05 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 295, Loss: 1.126870, Test Accuracy: 25.052683 %
# 	Total: 30.70 sec
# 	Train load: 23.37 sec; forward: 1.01 sec; backward: 2.08 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 296, Loss: 1.121258, Test Accuracy: 24.514289 %
# 	Total: 30.68 sec
# 	Train load: 23.37 sec; forward: 1.01 sec; backward: 2.10 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 297, Loss: 1.116909, Test Accuracy: 24.826532 %
# 	Total: 30.69 sec
# 	Train load: 23.37 sec; forward: 1.01 sec; backward: 2.09 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 298, Loss: 1.139547, Test Accuracy: 24.272075 %
# 	Total: 30.69 sec
# 	Train load: 23.36 sec; forward: 1.01 sec; backward: 2.08 sec
# 	Test load: 0.04 sec; forward: 0.23 sec; backward: 0.00 sec
# Train - Epoch 299, Loss: 1.115946, Test Accuracy: 24.618370 %
# 	Total: 30.69 sec
# ***************************** Train End *****************************
