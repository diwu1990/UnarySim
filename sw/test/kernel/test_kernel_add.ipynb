# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from UnarySim.sw.kernel.add import UnaryAdd
from UnarySim.sw.stream.gen import RNG, SourceGen, BSGen
from UnarySim.sw.metric.metric import ProgressiveError
import matplotlib.pyplot as plt
import time

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def add_test(rng="Sobol", row=128, col=10000, bitwidth=8):
    modes = ["bipolar", "unipolar"]

    scaled = [True, False]
    result_pe = []
    stype = torch.float
    btype = torch.float
    rtype = torch.float

    for mode in modes:
        for scale in scaled:
            run_time = 0
            acc_dim = 0
            result_pe_cycle = []
            uadd = UnaryAdd(mode=mode, scaled=scale, acc_dim=acc_dim).to(device)

            if mode == "unipolar":
                iVec = torch.rand(row, col).mul(2**bitwidth).round().div(2**bitwidth).to(device)
            elif mode == "bipolar":
                iVec = torch.rand(row, col).mul(2).sub(1).mul(2**bitwidth).round().div(2**bitwidth).to(device)
            
            oVec = torch.sum(iVec, acc_dim).to(device)

            iVecSource = SourceGen(iVec, bitwidth=bitwidth, mode=mode, rtype=rtype)().to(device)

            iVecRNG = RNG(bitwidth, 1, rng, rtype)().to(device)
            iVecBS = BSGen(iVecSource, iVecRNG, stype).to(device)

            iVecPE = ProgressiveError(iVec, scale=1, mode=mode).to(device)
            
            if scale is True:
                if acc_dim == 0:
                    oVecPE = ProgressiveError(oVec, scale=row, mode=mode).to(device)
                elif acc_dim ==1:
                    oVecPE = ProgressiveError(oVec, scale=col, mode=mode).to(device)
            else:
                oVecPE = ProgressiveError(oVec, scale=1, mode=mode).to(device)

            with torch.no_grad():
                idx = torch.zeros(iVecSource.size()).type(torch.long).to(device)
                for i in range(2**bitwidth):
                    iBS = iVecBS(idx + i)
                    iVecPE.Monitor(iBS)
                    
                    start_time = time.time()
                    oVecU = uadd(iBS)
                    run_time = time.time() - start_time + run_time
                    
                    oVecPE.Monitor(oVecU)
                    result_pe_cycle.append(1-torch.sqrt(torch.sum(torch.mul(oVecPE()[1], oVecPE()[1]))/col).item())
                print("--- %s seconds ---" % (run_time))
                print("input error: ", "min:", torch.min(iVecPE()[1]).item(), "max:", torch.max(iVecPE()[1]).item())
                print("output error: ", "min:", torch.min(oVecPE()[1]).item(), "max:", torch.max(oVecPE()[1]).item())
                result_pe = oVecPE()[1].cpu().numpy()
                print("error distribution=========>")
                plt.figure(figsize=(3,1.5))
                fig = plt.hist(result_pe, bins='auto')  # arguments are passed to np.histogram
                plt.title("data: "+mode+", scaled: "+str(scale))
                plt.show()
                print("progressive accuracy=========>")
                plt.figure(figsize=(3,1.5))
                fig = plt.plot(result_pe_cycle)  # arguments are passed to np.histogram
                plt.title("data: "+mode+", scaled: "+str(scale))
                plt.show()

# %%
rng = "Sobol"
row = 128
col = 10000
bitwidth = 8
add_test(rng, row, col, bitwidth)
# Out:
# --- 0.08001875877380371 seconds ---
# input error:  min: -0.0078125 max: 0.00390625
# output error:  min: -0.008453369140625 max: 0.00054931640625
# error distribution=========>
# progressive accuracy=========>
# --- 0.08402061462402344 seconds ---
# input error:  min: -0.0078125 max: 0.00390625
# output error:  min: -0.9609375 max: 0.1953125
# error distribution=========>
# progressive accuracy=========>
# --- 0.06801366806030273 seconds ---
# input error:  min: -0.00390625 max: 0.0
# output error:  min: -0.003936767578125 max: 0.0
# error distribution=========>
# progressive accuracy=========>
# --- 0.06601643562316895 seconds ---
# input error:  min: -0.00390625 max: 0.0
# output error:  min: 0.0 max: 0.0
# error distribution=========>
# progressive accuracy=========>

# %%
rng = "Race"
row = 128
col = 10000
add_test(rng, row, col)
# Out:
# --- 0.07601499557495117 seconds ---
# input error:  min: -0.00390625 max: 0.00390625
# output error:  min: -0.008453369140625 max: 0.00048828125
# error distribution=========>
# progressive accuracy=========>
# --- 0.0800163745880127 seconds ---
# input error:  min: -0.00390625 max: 0.00390625
# output error:  min: -0.0078125 max: 1.96875
# error distribution=========>
# progressive accuracy=========>
# --- 0.06401276588439941 seconds ---
# input error:  min: 0.0 max: 0.0
# output error:  min: -0.003875732421875 max: 0.0
# error distribution=========>
# progressive accuracy=========>
# --- 0.0690150260925293 seconds ---
# input error:  min: 0.0 max: 0.0
# output error:  min: 0.0 max: 0.0
# error distribution=========>
# progressive accuracy=========>

# %%
rng = "LFSR"
row = 128
col = 10000
add_test(rng, row, col)
# Out:
# --- 0.09105253219604492 seconds ---
# input error:  min: -0.01171875 max: 0.00390625
# output error:  min: -0.013336181640625 max: -0.00341796875
# error distribution=========>
# progressive accuracy=========>
# --- 0.08801960945129395 seconds ---
# input error:  min: -0.01171875 max: 0.00390625
# output error:  min: -0.4921875 max: 1.375
# error distribution=========>
# progressive accuracy=========>
# --- 0.06827044486999512 seconds ---
# input error:  min: -0.00390625 max: 0.0
# output error:  min: -0.004180908203125 max: -3.0517578125e-05
# error distribution=========>
# progressive accuracy=========>
# --- 0.07505083084106445 seconds ---
# input error:  min: -0.00390625 max: 0.0
# output error:  min: 0.0 max: 0.0
# error distribution=========>
# progressive accuracy=========>

# %%
rng = "SYS"
row = 128
col = 10000
add_test(rng, row, col)
# Out:
# --- 0.08101773262023926 seconds ---
# input error:  min: -0.00390625 max: 0.00390625
# output error:  min: -0.00848388671875 max: 0.00054931640625
# error distribution=========>
# progressive accuracy=========>
# --- 0.08101797103881836 seconds ---
# input error:  min: -0.00390625 max: 0.00390625
# output error:  min: -0.421875 max: 1.3359375
# error distribution=========>
# progressive accuracy=========>
# --- 0.06704878807067871 seconds ---
# input error:  min: 0.0 max: 0.0
# output error:  min: -0.003875732421875 max: 0.0
# error distribution=========>
# progressive accuracy=========>
# --- 0.0760185718536377 seconds ---
# input error:  min: 0.0 max: 0.0
# output error:  min: 0.0 max: 0.0
# error distribution=========>
# progressive accuracy=========>
