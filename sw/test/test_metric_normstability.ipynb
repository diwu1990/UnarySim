# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from UnarySim.sw.metric.metric import NormStability, Stability
from UnarySim.sw.bitstream.gen import RNG, SourceGen, BSGen
import random

# %%
width = 8
length = 2**width
device = torch.device("cuda:0")
device = torch.device("cpu")


for ite in range(length+1):
    dim = 1
    val = 1.0*ite/length
    val_tensor = torch.tensor([val])
#     print(val_tensor)
    val_bin = SourceGen(val_tensor, width, "unipolar")
#     print(val_bin())
    rng = RNG(width, dim, "Sobol").to(device)
#     print(rng())
    bs = BSGen(val_bin(), rng())
    normstb = NormStability(val_tensor, mode="unipolar", threshold=0.05).to(device)
    stb = Stability(val_tensor, mode="unipolar", threshold=0.05).to(device)
    for _ in range(length):
        a = bs(_)
#         print(a)
        normstb.Monitor(a)
        stb.Monitor(a)
    print(ite, val, normstb())
#     result = normstb()
# #     if result >= 1:
#     print("iter:", ite, "\n", "val:", val, "\n", "stab:", stb(), "\n", "norm stab:", result, "\n", "max_stab:", normstb.max_stab, "\n", "R:", normstb.R, "\n", "l_p:", normstb.l_p)
#     print("stab", stb())
#     print("norm stab", normstb())
#     print("norm stab: max stab", normstb.max_stab)
# Out:
# 0 0.0 tensor([1.])
# 1 0.00390625 tensor([1.])
# 2 0.0078125 tensor([1.])
# 3 0.01171875 tensor([1.])
# 4 0.015625 tensor([1.])
# 5 0.01953125 tensor([1.])
# 6 0.0234375 tensor([1.])
# 7 0.02734375 tensor([1.])
# 8 0.03125 tensor([1.])
# 9 0.03515625 tensor([1.])
# 10 0.0390625 tensor([1.])
# 11 0.04296875 tensor([1.])
# 12 0.046875 tensor([1.])
# 13 0.05078125 tensor([0.8863])
# 14 0.0546875 tensor([0.9417])
# 15 0.05859375 tensor([0.9417])
# 16 0.0625 tensor([0.9417])
# 17 0.06640625 tensor([1.])
# 18 0.0703125 tensor([1.])
# 19 0.07421875 tensor([0.9758])
# 20 0.078125 tensor([0.9758])
# 21 0.08203125 tensor([0.9758])
# 22 0.0859375 tensor([0.9113])
# 23 0.08984375 tensor([0.9113])
# 24 0.09375 tensor([0.9113])
# 25 0.09765625 tensor([0.9758])
# 26 0.1015625 tensor([0.9758])
# 27 0.10546875 tensor([0.9758])
# 28 0.109375 tensor([0.9758])
# 29 0.11328125 tensor([0.9758])
# 30 0.1171875 tensor([0.9113])
# 31 0.12109375 tensor([0.9113])
# 32 0.125 tensor([0.9113])
# ...

# %%
width = 6
length = 2**width

for ite in range(length+1):
    dim = 1
    val = 1.0*ite/length
#     val = 0.18
#     print(val)
    val_tensor = torch.tensor([[val, 1-val]]).cuda()
#     print(val_tensor)
    val_bin = SourceGen(val_tensor, width, "unipolar")
#     print(val_bin())
    rng = RNG(width, dim, "Sobol").cuda()
    bs = BSGen(val_bin(), rng())
    normstb = NormStability(val_tensor, mode="unipolar", threshold=0.05).cuda()
    stb = Stability(val_tensor, mode="unipolar", threshold=0.05).cuda()
    for _ in range(length):
        a = bs(_)
    #     print(a)
        normstb.Monitor(a)
        stb.Monitor(a)
    print(ite, normstb(), normstb.R*normstb.l_p)
#     result = normstb()
# #     if result >= 1:
#     print("iter:", ite, "\n", "val:", val, "\n", "stab:", stb(), "\n", "norm stab:", result, "\n", "max_stab:", normstb.max_stab, "\n", "R:", normstb.R, "\n", "l_p:", normstb.l_p)
#     print("stab", stb())
#     print("norm stab", normstb())
#     print("norm stab: max stab", normstb.max_stab)
# Out:
# 0 tensor([[1., 1.]], device='cuda:0') tensor([[0., 0.]], device='cuda:0')
# 1 tensor([[1., 1.]], device='cuda:0') tensor([[0., 0.]], device='cuda:0')
# 2 tensor([[1., 1.]], device='cuda:0') tensor([[0., 0.]], device='cuda:0')
# 3 tensor([[1., 1.]], device='cuda:0') tensor([[0., 0.]], device='cuda:0')
# 4 tensor([[0.5397, 0.8730]], device='cuda:0') tensor([[0., 0.]], device='cuda:0')
# 5 tensor([[0.8929, 0.9821]], device='cuda:0') tensor([[8., 8.]], device='cuda:0')
# 6 tensor([[0.6071, 0.9821]], device='cuda:0') tensor([[8., 8.]], device='cuda:0')
# 7 tensor([[0.8929, 0.7857]], device='cuda:0') tensor([[8., 8.]], device='cuda:0')
# 8 tensor([[0.6071, 0.9464]], device='cuda:0') tensor([[8., 8.]], device='cuda:0')
# 9 tensor([[0.8929, 0.9643]], device='cuda:0') tensor([[8., 8.]], device='cuda:0')
# 10 tensor([[0.6071, 1.0000]], device='cuda:0') tensor([[8., 8.]], device='cuda:0')
# 11 tensor([[0.8929, 0.8393]], device='cuda:0') tensor([[8., 8.]], device='cuda:0')
# ...

# %%
width = 6
length = 2**width

for ite in range(length+1):
    dim = 1
    val = 1.0*ite/length
#     val = 0.18
#     print(val)
    val_tensor = torch.tensor([[[val, 1-val]]]).cuda()
#     print(val_tensor)
    val_bin = SourceGen(val_tensor, width, "unipolar")
#     print(val_bin())
    rng = RNG(width, dim, "Sobol").cuda()
    bs = BSGen(val_bin(), rng())
    normstb = NormStability(val_tensor, mode="unipolar", threshold=0.05).cuda()
    stb = Stability(val_tensor, mode="unipolar", threshold=0.05).cuda()
    for _ in range(length):
        a = bs(_)
    #     print(a)
        normstb.Monitor(a)
        stb.Monitor(a)
    print(ite, normstb(), normstb.R*normstb.l_p)
#     result = normstb()
# #     if result >= 1:
#     print("iter:", ite, "\n", "val:", val, "\n", "stab:", stb(), "\n", "norm stab:", result, "\n", "max_stab:", normstb.max_stab, "\n", "R:", normstb.R, "\n", "l_p:", normstb.l_p)
#     print("stab", stb())
#     print("norm stab", normstb())
#     print("norm stab: max stab", normstb.max_stab)
# Out:
# 0 tensor([[[1., 1.]]], device='cuda:0') tensor([[[0., 0.]]], device='cuda:0')
# 1 tensor([[[1., 1.]]], device='cuda:0') tensor([[[0., 0.]]], device='cuda:0')
# 2 tensor([[[1., 1.]]], device='cuda:0') tensor([[[0., 0.]]], device='cuda:0')
# 3 tensor([[[1., 1.]]], device='cuda:0') tensor([[[0., 0.]]], device='cuda:0')
# 4 tensor([[[0.5397, 0.8730]]], device='cuda:0') tensor([[[0., 0.]]], device='cuda:0')
# 5 tensor([[[0.8929, 0.9821]]], device='cuda:0') tensor([[[8., 8.]]], device='cuda:0')
# 6 tensor([[[0.6071, 0.9821]]], device='cuda:0') tensor([[[8., 8.]]], device='cuda:0')
# 7 tensor([[[0.8929, 0.7857]]], device='cuda:0') tensor([[[8., 8.]]], device='cuda:0')
# 8 tensor([[[0.6071, 0.9464]]], device='cuda:0') tensor([[[8., 8.]]], device='cuda:0')
# 9 tensor([[[0.8929, 0.9643]]], device='cuda:0') tensor([[[8., 8.]]], device='cuda:0')
# 10 tensor([[[0.6071, 1.0000]]], device='cuda:0') tensor([[[8., 8.]]], device='cuda:0')
# ...

# %%
width = 6
length = 2**width

for ite in range(length+1):
    dim = 1
    val = 1.0*ite/length
#     val = 0.18
#     print(val)
    val_tensor = torch.tensor([[[[val, 1-val]]]]).cuda()
#     print(val_tensor)
    val_bin = SourceGen(val_tensor, width, "unipolar")
#     print(val_bin())
    rng = RNG(width, dim, "Sobol").cuda()
    bs = BSGen(val_bin(), rng())
    normstb = NormStability(val_tensor, mode="unipolar", threshold=0.05).cuda()
    stb = Stability(val_tensor, mode="unipolar", threshold=0.05).cuda()
    for _ in range(length):
        a = bs(_)
    #     print(a)
        normstb.Monitor(a)
        stb.Monitor(a)
    print(ite, normstb(), normstb.R*normstb.l_p)
#     result = normstb()
# #     if result >= 1:
#     print("iter:", ite, "\n", "val:", val, "\n", "stab:", stb(), "\n", "norm stab:", result, "\n", "max_stab:", normstb.max_stab, "\n", "R:", normstb.R, "\n", "l_p:", normstb.l_p)
#     print("stab", stb())
#     print("norm stab", normstb())
#     print("norm stab: max stab", normstb.max_stab)
# Out:
# 0 tensor([[[[1., 1.]]]], device='cuda:0') tensor([[[[0., 0.]]]], device='cuda:0')
# 1 tensor([[[[1., 1.]]]], device='cuda:0') tensor([[[[0., 0.]]]], device='cuda:0')
# 2 tensor([[[[1., 1.]]]], device='cuda:0') tensor([[[[0., 0.]]]], device='cuda:0')
# 3 tensor([[[[1., 1.]]]], device='cuda:0') tensor([[[[0., 0.]]]], device='cuda:0')
# 4 tensor([[[[0.5397, 0.8730]]]], device='cuda:0') tensor([[[[0., 0.]]]], device='cuda:0')
# 5 tensor([[[[0.8929, 0.9821]]]], device='cuda:0') tensor([[[[8., 8.]]]], device='cuda:0')
# 6 tensor([[[[0.6071, 0.9821]]]], device='cuda:0') tensor([[[[8., 8.]]]], device='cuda:0')
# 7 tensor([[[[0.8929, 0.7857]]]], device='cuda:0') tensor([[[[8., 8.]]]], device='cuda:0')
# 8 tensor([[[[0.6071, 0.9464]]]], device='cuda:0') tensor([[[[8., 8.]]]], device='cuda:0')
# 9 tensor([[[[0.8929, 0.9643]]]], device='cuda:0') tensor([[[[8., 8.]]]], device='cuda:0')
# 10 tensor([[[[0.6071, 1.0000]]]], device='cuda:0') tensor([[[[8., 8.]]]], device='cuda:0')
# ...
